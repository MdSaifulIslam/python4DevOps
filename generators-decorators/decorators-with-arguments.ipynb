# %% [markdown]
# ## Configurable Decorators: Decorators with Arguments
#
# - A basic decorator adds fixed behavior; sometimes you need to *configure* that behaviour (e.g. how many retries, which log level).
# - You cannot pass options directly to a plain `@decorator`, because that decorator receives only the target function.
# - Solution: call a *factory* that takes options and returns a decorator, then apply it with `@factory(option=value)`.

# %% [markdown]
# ## The Decorator Factory Pattern
#
# - **Factory function** receives configuration arguments and returns the **actual decorator**.
# - The actual **decorator** still takes the target function and builds a **wrapper**.
# - The wrapper can access both the factory’s configuration (via a closure) and the call‑time `*args / **kwargs` for the target function.
# - Three nested layers keep concerns separated: configuration ➜ decoration ➜ runtime.
#
# ### Applying Decorators with Arguments
#
# - Use `@factory(arg1, arg2…)` above the function definition.
# - At *definition* time Python calls the factory, gets back a decorator, and applies that decorator to the function.
# - Callers of the function automatically get the behaviour configured by the factory.
#
# ## Example: Retry Decorator Factory
#
# - A practical DevOps scenario: retry a flaky operation a configurable number of times.
# - The factory takes `max_attempts`; the wrapper loops until success or until attempts are exhausted, re‑raising the last error.

# %%
import random

# def retry(func):
#     max_attempts = 5

#     def wrapper(*args, **kwargs):
#         for attempt in range(1, max_attempts + 1):
#             try:
#                 print(f"Attempt {attempt}/{max_attempts}")
#                 return func(*args, **kwargs)
#             except Exception as e:
#                 print(f"Error: {e}")
#                 # if attempt == max_attempts:
#                     # raise
#     return wrapper

# def retry(max_attempts = 3):
#     def decorator(func):
#         def wrapper(*args, **kwargs):
#             for attempt in range(1, max_attempts + 1):
#                 try:
#                     print(f"Attempt {attempt}/{max_attempts}")
#                     return func(*args, **kwargs)
#                 except Exception as e:
#                     print(f"Error: {e}")
#                     # if attempt == max_attempts:
#                         # raise
#         return wrapper
#     return decorator

# @retry(5)
# def sometimes_fail():
#     if random.random() < 0.7:
#         raise RuntimeError("Flaky failure")
#     return "Success"

# print(f"Result: {sometimes_fail()}")


import random

def logger(prefix="pre"):
    # This level "sees" the prefix
    def retry(max_attempts=3):
        # This level "sees" both prefix AND max_attempts
        def decorator(func):
            # This level "sees" prefix, max_attempts, AND the function
            def wrapper(*args, **kwargs):
                print(f"Starting process for {func.__name__}")
                for attempt in range(1, max_attempts + 1):
                    try:
                        print(f"[{prefix}] Attempt {attempt}/{max_attempts}")
                        return func(*args, **kwargs)
                    except Exception as e:
                        print(f"Error: {e}")
                        if max_attempts == attempt:
                            raise
                return None
            return wrapper
        return decorator
    return retry

# HOW TO USE IT:
# Notice the double parentheses! 
# logger("PROD") returns the 'retry' function.
# retry(max_attempts=3) returns the 'decorator' function.
@logger("PROD")(max_attempts=3)
def sometimes_fail():
    if random.random() < 0.7:
        raise RuntimeError("Cloud Timeout")
    return "Success"

print(f"Result: {sometimes_fail()}")
# Out:
# Starting process for sometimes_fail
# [PROD] Attempt 1/3
# Error: Cloud Timeout
# [PROD] Attempt 2/3
# Error: Cloud Timeout
# [PROD] Attempt 3/3
# Error: Cloud Timeout
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 73
#      70         raise RuntimeError("Cloud Timeout")
#      71     return "Success"
# ---> 73 print(f"Result: {sometimes_fail()}")
#
# Cell In[6], line 53, in logger.<locals>.retry.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      51 try:
#      52     print(f"[{prefix}] Attempt {attempt}/{max_attempts}")
# ---> 53     return func(*args, **kwargs)
#      54 except Exception as e:
#      55     print(f"Error: {e}")
#
# Cell In[6], line 70, in sometimes_fail()
#      67 @logger("PROD")(max_attempts=3)
#      68 def sometimes_fail():
#      69     if random.random() < 0.7:
# ---> 70         raise RuntimeError("Cloud Timeout")
#      71     return "Success"
#
# RuntimeError: Cloud Timeout
